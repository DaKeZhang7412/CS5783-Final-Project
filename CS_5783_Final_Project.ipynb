# %% [markdown]
# <a href="https://colab.research.google.com/github/DaKeZhang7412/CS5783-Final-Project/blob/main/CS_5783_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy.io
mat = scipy.io.loadmat('test_32x32.mat')

print(type(mat))
mat

# %%
# import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
# %matplotlib inline

image_ind = 8



train_data = sio.loadmat('train_32x32.mat')

for i in range(5,20):
    # access to the dict
    x = train_data['X']
    y = train_data['y']

    # show sample
    plt.imshow(x[:,:,:,i])
    plt.show()


    print (y[i])
# Out:
# [5]
# [9]
# [3]
# [3]
# [1]
# [3]
# [3]
# [2]
# [8]
# [7]
# [4]
# [4]
# [1]
# [2]
# [8]
